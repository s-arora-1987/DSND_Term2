# %% [markdown]
# ### Content Based Recommendations
#
# In the previous notebook, you were introduced to a way to make recommendations using collaborative filtering.  However, using this technique there are a large number of users who were left without any recommendations at all.  Other users were left with fewer than the ten recommendations that were set up by our function to retrieve...
#
# In order to help these users out, let's try another technique **content based** recommendations.  Let's start off where we were in the previous notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from IPython.display import HTML
import progressbar
import tests as t
import pickle


# %matplotlib inline

# Read in the datasets
movies = pd.read_csv('movies_clean.csv')
reviews = pd.read_csv('reviews_clean.csv')

del movies['Unnamed: 0']
del reviews['Unnamed: 0']


all_recs = pickle.load(open("all_recs.p", "rb"))

# %% [markdown]
# ### Datasets
#
# From the above, you now have access to three important items that you will be using throughout the rest of this notebook.
#
# `a.` **movies** - a dataframe of all of the movies in the dataset along with other content related information about the movies (genre and date)
#
#
# `b.` **reviews** - this was the main dataframe used before for collaborative filtering, as it contains all of the interactions between users and movies.
#
#
# `c.` **all_recs** - a dictionary where each key is a user, and the value is a list of movie recommendations based on collaborative filtering
#
# For the individuals in **all_recs** who did recieve 10 recommendations using collaborative filtering, we don't really need to worry about them.  However, there were a number of individuals in our dataset who did not receive any recommendations.
#
# -----
#
# `1.` To begin, let's start with finding all of the users in our dataset who didn't get all 10 ratings we would have liked them to have using collaborative filtering.

# %%
list(all_recs.keys())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-73d37985e6b6> in <module>
# ----> 1 list(all_recs.keys())-[2,3]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
users_with_all_recs = [uid for uid in list(all_recs.keys()) if (len(all_recs[uid]) >= 10)] # Store user ids who have all their recommendations in this (10 or more)
users_who_need_recs = [uid for uid in list(all_recs.keys()) if uid not in users_with_all_recs] # Store users who still need recommendations here

# %%
# A quick test
assert len(users_with_all_recs) == 22187
print("That's right there were still another 31781 users who needed recommendations when we only used collaborative filtering!")
# Out:
# That's right there were still another 31781 users who needed recommendations when we only used collaborative filtering!

# %% [markdown]
# ### Content Based Recommendations
#
# You will be doing a bit of a mix of content and collaborative filtering to make recommendations for the users this time.  This will allow you to obtain recommendations in many cases where we didn't make recommendations earlier.
#
# `2.` Before finding recommendations, rank the user's ratings from highest ratings to lowest ratings. You will move through the movies in this order looking for other similar movies.

# %%
# create a dataframe similar to reviews, but ranked by rating for each user
ratingRanked_reviews = reviews.sort_values(by=['user_id','rating'],ascending=False)

# %%
ratingRanked_reviews.head(5)
# Out:
#         user_id  movie_id  rating   timestamp                 date
# 876364    68310   1623205       6  1362832655  2013-03-09 07:37:35
# 876362    68309    172495      10  1587107015  2020-04-17 03:03:35
# 876363    68309    414387      10  1587107852  2020-04-17 03:17:32
# 876327    68308   5563334       7  1580591770  2020-02-01 16:16:10
# 876337    68308   6394270       7  1582666211  2020-02-25 16:30:11

# %% [markdown]
# ### Similarities
#
# In the collaborative filtering sections, you became quite familiar with different methods of determining the similarity (or distance) of two users.  We can perform similarities based on content in much the same way.
#
# In many cases, it turns out that one of the fastest ways we can find out how similar items are to one another (when our matrix isn't totally sparse like it was in the earlier section) is by simply using matrix multiplication.  If you are not familiar with this, an explanation is available [here by 3blue1brown](https://www.youtube.com/watch?v=LyGKycYT2v0) and another quick explanation is provided [on the post here](https://math.stackexchange.com/questions/689022/how-does-the-dot-product-determine-similarity).
#
# For us to pull out a matrix that describes the movies in our dataframe in terms of content, we might just use the indicator variables related to **year** and **genre** for our movies.
#
# Then we can obtain a matrix of how similar movies are to one another by taking the dot product of this matrix with itself.  Notice in the below that the dot product where our 1 values overlap gives a value of 2 indicating higher similarity.  In the second dot product, the 1 values don't match up.  This leads to a dot product of 0 indicating lower similarity.
#
# <img src="images/dotprod1.png" alt="Dot Product" height="500" width="500">
#
# We can perform the dot product on a matrix of movies with content characteristics to provide a movie by movie matrix where each cell is an indication of how similar two movies are to one another.  In the below image, you can see that movies 1 and 8 are most similar, movies 2 and 8 are most similar and movies 3 and 9 are most similar for this subset of the data.  The diagonal elements of the matrix will contain the similarity of a movie with itself, which will be the largest possible similarity (which will also be the number of 1's in the movie row within the orginal movie content matrix.
#
# <img src="images/moviemat.png" alt="Dot Product" height="500" width="500">
#
#
# `3.` Create a numpy array that is a matrix of indicator variables related to year (by century) and movie genres by movie.  Perform the dot prodoct of this matrix with itself (transposed) to obtain a similarity matrix of each movie with every other movie.  The final matrix should be 31245 x 31245.

# %%
movies.head(5)
movies.drop(columns=['genre'],inplace=True)
movieidIndexedMoviesDF = movies.set_index('movie_id')
movieidIndexedMoviesDF
# Out:
#                                             movie  War  Comedy  Crime  Adult  \
# movie_id
# 8         Edison Kinetoscopic Record of a Sneeze     0       0      0      0
# 10                  La sortie des usines Lumière     0       0      0      0
# 12                        The Arrival of a Train     0       0      0      0
# 91                           Le manoir du diable     0       0      0      0
# 131                            Une nuit terrible     0       1      0      0
# ...                                           ...  ...     ...    ...    ...
# 12393526                                 Bulbbul     0       0      0      0
# 12397778            A Hundred Years of Happiness     0       0      0      0
# 12498582            Bhanumathi &amp; Ramakrishna     0       1      0      0
# 12498618                                    8:46     0       1      0      0
# 12574336                                Homemade     0       0      0      0
#
#           Short  Music  Action  Mystery  Adventure  ...  Sci-Fi  Game-Show  \
# movie_id                                            ...
# 8             1      0       0        0          0  ...       0          0
# 10            1      0       0        0          0  ...       0          0
# 12            1      0       0        0          0  ...       0          0
# 91            1      0       0        0          0  ...       0          0
# 131           1      0       0        0          0  ...       0          0
# ...         ...    ...     ...      ...        ...  ...     ...        ...
# 12393526      0      0       0        0          0  ...       0          0
# 12397778      0      0       0        0          0  ...       0          0
# 12498582      0      0       0        0          0  ...       0          0
# 12498618      0      0       0        0          0  ...       0          0
# 12574336      0      0       0        0          0  ...       0          0
#
#           Family  Western  News  Documentary  Thriller  century_18  \
# movie_id
# 8              0        0     0            1         0           1
# 10             0        0     0            1         0           1
# 12             0        0     0            1         0           1
# 91             0        0     0            0         0           1
# 131            0        0     0            0         0           1
# ...          ...      ...   ...          ...       ...         ...
# 12393526       0        0     0            0         0           0
# 12397778       0        0     0            1         0           0
# 12498582       0        0     0            0         0           0
# 12498618       0        0     0            0         0           0
# 12574336       0        0     0            0         0           0
#
#           century_19  century_20
# movie_id
# 8                  0           0
# 10                 0           0
# 12                 0           0
# 91                 0           0
# 131                0           0
# ...              ...         ...
# 12393526           0           1
# 12397778           0           1
# 12498582           0           1
# 12498618           0           1
# 12574336           0           1
#
# [35672 rows x 32 columns]

# %%
list_cols = list(movieidIndexedMoviesDF.columns)
list_cols.remove('movie')
print(list_cols)
# Out:
# ['War', 'Comedy', 'Crime', 'Adult', 'Short', 'Music', 'Action', 'Mystery', 'Adventure', 'Reality-TV', 'Talk-Show', 'Biography', 'Romance', 'Sport', 'Film-Noir', 'Drama', 'History', 'Animation', 'Horror', 'Fantasy', 'Musical', 'Sci-Fi', 'Game-Show', 'Family', 'Western', 'News', 'Documentary', 'Thriller', 'century_18', 'century_19', 'century_20']

# %%
a = [[1, 0], [0, 1]]
np.dot(a,a)
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
# Subset so movie_content is only using the dummy variables for each genre and the 3 century based year dummy columns
list_cols = list(movieidIndexedMoviesDF.columns)
list_cols.remove('movie')
movie_content = np.array(movieidIndexedMoviesDF[list_cols])

# Take the dot product to obtain a movie x movie matrix of similarities
dot_prod_movies = np.dot(movie_content,np.transpose(movie_content))

# %%
# create checks for the dot product matrix
assert dot_prod_movies.shape[0] == 35672
assert dot_prod_movies.shape[1] == 35672
assert dot_prod_movies[0, 0] == np.max(dot_prod_movies[0])
max_ind = dot_prod_movies.shape[0]-1
assert dot_prod_movies[max_ind,max_ind] == np.max(dot_prod_movies[max_ind])
print("Looks like you passed all of the tests.  Though they weren't very robust - if you want to write some of your own, I won't complain!")
# Out:
# Looks like you passed all of the tests.  Though they weren't very robust - if you want to write some of your own, I won't complain!

# %% [markdown]
# ### For Each User...
#
#
# Now that you have a matrix where each user has their ratings ordered.  You also have a second matrix where movies are each axis, and the matrix entries are larger where the two movies are more similar and smaller where the two movies are dissimilar.  This matrix is a measure of content similarity. Therefore, it is time to get to the fun part.
#
# For each user, we will perform the following:
#
#     i. For each movie, find the movies that are most similar that the user hasn't seen.
#
#     ii. Continue through the available, rated movies until 10 recommendations or until there are no additional movies.
#
# As a final note, you may need to adjust the criteria for 'most similar' to obtain 10 recommendations.  As a first pass, I used only movies with the highest possible similarity to one another as similar enough to add as a recommendation.
#
# `3.` In the below cell, complete each of the functions needed for making content based recommendations.

# %%
movieidIndexedMoviesDF.head(4)
# Out:
#                                             movie  War  Comedy  Crime  Adult  \
# movie_id
# 8         Edison Kinetoscopic Record of a Sneeze     0       0      0      0
# 10                  La sortie des usines Lumière     0       0      0      0
# 12                        The Arrival of a Train     0       0      0      0
# 91                           Le manoir du diable     0       0      0      0
#
#           Short  Music  Action  Mystery  Adventure  ...  Sci-Fi  Game-Show  \
# movie_id                                            ...
# 8             1      0       0        0          0  ...       0          0
# 10            1      0       0        0          0  ...       0          0
# 12            1      0       0        0          0  ...       0          0
# 91            1      0       0        0          0  ...       0          0
#
#           Family  Western  News  Documentary  Thriller  century_18  \
# movie_id
# 8              0        0     0            1         0           1
# 10             0        0     0            1         0           1
# 12             0        0     0            1         0           1
# 91             0        0     0            0         0           1
#
#           century_19  century_20
# movie_id
# 8                  0           0
# 10                 0           0
# 12                 0           0
# 91                 0           0
#
# [4 rows x 32 columns]

# %%
np.where(movies['movie_id']==12)[0][0]
# Out:
# 2

# %%
movieidIndexedMoviesDF.index[1]
dot_prod_movies[0:5,0:5]
# Out:
# array([[3, 3, 3, 2, 2],
#        [3, 3, 3, 2, 2],
#        [3, 3, 3, 2, 2],
#        [2, 2, 2, 3, 3],
#        [2, 2, 2, 3, 4]])

# %%
def find_similar_movies(movie_id):
    '''
    INPUT
    movie_id - a movie_id 
    OUTPUT
    similar_movies - an array of the most similar movies by title
    '''
    # find the row of each movie id
    pos_mv = np.where(movies['movie_id']==movie_id)[0][0]
    
    # find the most similar movie indices - to start I said they need to be the same for all content
    # retrieve ids from movieidIndexedMoviesDF based on positions in row
    row = dot_prod_movies[pos_mv,:]
    poses_sim_movs = np.where(row > 0)
    sim_mov_ids = [movieidIndexedMoviesDF.index[pos] for pos in poses_sim_movs]
    list_form = list(sim_mov_ids[0])
    # remove the movie itself
    list_form.remove(movie_id)
    
    # pull the movie titles based on the indices
    similar_movies = get_movie_names(list_form)
    
    return similar_movies
    
# You made this function in an earlier notebook - using again here    
def get_movie_names(movie_ids):
    '''
    INPUT
    movie_ids - a list of movie_ids
    OUTPUT
    movies - a list of movie names associated with the movie_ids
    
    '''

    movie_lst = list(movies[movies['movie_id'].isin(movie_ids)]['movie'])
   
    return movie_lst

find_similar_movies(10)
# Out:
# ['Edison Kinetoscopic Record of a Sneeze ',
#  'The Arrival of a Train ',
#  'Le manoir du diable ',
#  'Une nuit terrible ',
#  'A Trip to the Moon ',
#  'The Great Train Robbery ',
#  'The Adventures of Dollie ',
#  'The Country Doctor ',
#  'Frankenstein ',
#  'The Lonedale Operator ',
#  'Max et Jane veulent faire du théâtre ',
#  'Dough and Dynamite ',
#  'His Musical Career ',
#  'His New Profession ',
#  'Laughing Gas ',
#  'The New Janitor ',
#  'The Ocean Waif ',
#  'Recreation ',
#  'The Rounders ',
#  'The Bank ',
#  'The Champion ',
#  'A Jitney Elopement ',
#  'The Tramp ',
#  'Behind the Screen ',
#  'The Fireman ',
#  'The Floorwalker ',
#  'One A.M. ',
#  'The Pawnshop ',
#  'The Rink ',
#  'The Vagabond ',
#  'The Cure ',
#  'Easy Street ',
#  'The Immigrant ',
#  "A Dog's Life ",
#  'Take a Chance ',
#  'Godovshchina revolyutsii ',
#  'His Royal Slyness ',
#  'Young Mr. Jazz ',
#  'Neighbors ',
#  'One Week ',
#  'The Scarecrow ',
#  'The Goat ',
#  "The 'High Sign' ",
#  'Cops ',
#  'The Electric House ',
#  'Häxan ',
#  'Nanook of the North ',
#  'Pay Day ',
#  'The Balloonatic ',
#  "Alice's Spooky Adventure ",
#  "Entr'acte ",
#  'Kinoglaz ',
#  'West of Hot Dog ',
#  'Shakhmatnaya goryachka ',
#  'Along Came Auntie ',
#  'Crazy Like a Fox ',
#  '45 Minutes from Hollywood ',
#  'Berlin: Die Sinfonie der Grosstadt ',
#  'Call of the Cuckoo ',
#  'Duck Soup ',
#  "Love 'Em and Weep ",
#  'Putting Pants on Philip ',
#  'Sailors, Beware! ',
#  'The Second 100 Years ',
#  'Sugar Daddies ',
#  'With Love and Hisses ',
#  'Early to Bed ',
#  'The Finishing Touch ',
#  "Leave 'Em Laughing ",
#  'Should Married Men Go Home? ',
#  'Steamboat Willie ',
#  'Their Purple Moment ',
#  'Two Tars ',
#  'We Faw Down ',
#  "You're Darn Tootin' ",
#  'Berth Marks ',
#  'Big Business ',
#  'Chelovek s kino-apparatom ',
#  'Double Whoopee ',
#  'Drifters ',
#  'The Hoose-Gow ',
#  "Men O'War ",
#  'Perfect Day ',
#  "That's My Wife ",
#  'They Go Boom! ',
#  'Un chien andalou ',
#  'Unaccustomed As We Are ',
#  'Another Fine Mess ',
#  'Below Zero ',
#  'Blotto ',
#  'Brats ',
#  'The Golf Specialist ',
#  'Hog Wild ',
#  'The Laurel-Hardy Murder Case ',
#  'Night Owls ',
#  'À propos de Nice ',
#  'Beau Hunks ',
#  'Chickens Come Home- ',
#  'Come Clean ',
#  'Laughing Gravy ',
#  "Taris, roi de l'eau ",
#  'Any Old Port! ',
#  "Buzzin' Around ",
#  'County Hospital ',
#  'The Dentist ',
#  "The Devil's Cabaret ",
#  'The Fatal Glass of Beer ',
#  'Helpmates ',
#  'Las Hurdes ',
#  'The Music Box ',
#  'On the Loose ',
#  'Scram! ',
#  'Their First Mistake ',
#  'Towed in a Hole ',
#  'Busy Bodies ',
#  'Dirty Work ',
#  'Me and My Pal ',
#  'The Midnight Patrol ',
#  'Three Little Pigs ',
#  'Twice Two ',
#  'Zéro de conduite: Jeunes diables au collège ',
#  'Going Spanish ',
#  'The Live Ghost ',
#  'Man of Aran ',
#  'Oliver the Eighth ',
#  'On demande une brute ',
#  'Peculiar Penguins ',
#  'Them Thar Hills ',
#  'Triumph des Willens ',
#  'The Fixer Uppers ',
#  'Gai dimanche! ',
#  'Thicker Than Water ',
#  'Tit for Tat ',
#  'Half Shot Shooters ',
#  'Night Mail ',
#  'Popeye the Sailor Meets Sindbad the Sailor ',
#  'Soigne ton gauche ',
#  'Partie de campagne ',
#  'Cash and Carry ',
#  'Spaansche aarde ',
#  'Olympia 1. Teil - Fest der Völker ',
#  'Olympia 2. Teil - Fest der Schönheit ',
#  'Oily to Bed, Oily to Rise ',
#  'How High Is Up? ',
#  'The Old South ',
#  'You Nazty Spy! ',
#  'The Gay Parisian ',
#  'Fraidy Cat ',
#  'Listen to Britain ',
#  'The Magic of Make-up ',
#  'Matri-Phony ',
#  'Prelude to War ',
#  'The Memphis Belle: A Story of a Flying Fortress ',
#  'Meshes of the Afternoon ',
#  'Saludos Amigos ',
#  'Three Little Twirps ',
#  'Victory Through Air Power ',
#  'Aventure malgache ',
#  'The Battle of Russia ',
#  'San Pietro ',
#  'Bon Voyage ',
#  "The Yoke's on Me ",
#  'The Zoot Cat ',
#  'Flirty Birdy ',
#  'Micro-Phonies ',
#  'De ware glorie ',
#  'Let There Be Light ',
#  'The Potted Psalm ',
#  'Trap Happy ',
#  'The Cat Concerto ',
#  'Dr. Jekyll and Mr. Mouse ',
#  "L'école des facteurs ",
#  'Professor Tom ',
#  'A-Haunting We Will Go ',
#  'The Cat and the Mermouse ',
#  'Le sang des bêtes ',
#  'Day of the Fight ',
#  'Kon-Tiki ',
#  'Little Quacker ',
#  "Un chant d'amour ",
#  'Flying Padre: An RKO-Pathe Screenliner ',
#  'Jerry and the Goldfish ',
#  'Nit-Witty Kitty ',
#  'Cruise Cat ',
#  'Feed the Kitty ',
#  'Lambert the Sheepish Lion ',
#  'Neighbours ',
#  "Pluto's Christmas Tree ",
#  'The Seafarers ',
#  'Triplet Trouble ',
#  'Duck Amuck ',
#  'Duck Dodgers in the 24½th Century ',
#  'The Missing Mouse ',
#  'The Pleasure Garden ',
#  "That's My Pup! ",
#  'Touché, Pussy Cat! ',
#  'Les maîtres fous ',
#  'Nuit et brouillard ',
#  'Le ballon rouge ',
#  'Seven Wonders of the World ',
#  'Toute la mémoire du monde ',
#  'Ali Baba Bunny ',
#  'Lettre de Sibérie ',
#  'Les mistons ',
#  'Du côté de la côte ',
#  'Free Radicals ',
#  'Hare-Way to the Stars ',
#  'The Legend of Sleepy Hollow ',
#  'Ubiytsy ',
#  "Une histoire d'eau ",
#  "Jazz on a Summer's Day ",
#  'The Making of the President 1960 ',
#  'Heureux anniversaire ',
#  'La jetée ',
#  'La rivière du hibou ',
#  'La boulangère de Monceau ',
#  'Mondo cane ',
#  'Mourir à Madrid ',
#  'Salut les Cubains ',
#  'Point of Order! ',
#  'Scorpio Rising ',
#  'The T.A.M.I. Show ',
#  'A Charlie Brown Christmas ',
#  'Obyknovennyy fashizm ',
#  'Tôkyô orinpikku ',
#  'Yûkoku ',
#  'Borom sarret ',
#  'The Endless Summer ',
#  'Freiheit ',
#  'Helicopter Canada ',
#  "Hold Me While I'm Naked ",
#  "It's the Great Pumpkin, Charlie Brown ",
#  'John F. Kennedy: Years of Lightning, Day of Drums ',
#  'Rosalie ',
#  'Six Figures Getting Sick ',
#  'Der Stadtstreicher ',
#  'The Big Shave ',
#  'Cours du soir ',
#  'Dont Look Back ',
#  'Electronic Labyrinth THX 1138 4EB ',
#  'The Alphabet ',
#  'Calcutta ',
#  'Dom kallar oss mods ',
#  'Filmmaker ',
#  'Sympathy for the Devil ',
#  'Z miasta Lodzi ',
#  "Amblin' ",
#  'Bambi Meets Godzilla ',
#  "The Blues Accordin' to Lightnin' Hopkins ",
#  'En marchant ',
#  'In the Year of the Pig ',
#  'Monterey Pop ',
#  'Salesman ',
#  'British Sounds ',
#  "Elvis: That's the Way It Is ",
#  'Erinnerungen an die Zukunft ',
#  'Gimme Shelter ',
#  'The Grandmother ',
#  'King: A Filmed Record... Montgomery to Memphis ',
#  'Let It Be ',
#  'Cuadecuc, vampir ',
#  'Woodstock ',
#  'Le chagrin et la pitié ',
#  'Fata Morgana ',
#  'Mad Dogs & Englishmen ',
#  'Land des Schweigens und der Dunkelheit ',
#  'On Any Sunday ',
#  'The Selfish Giant ',
#  'A Charlie Brown Thanksgiving ',
#  'Elvis on Tour ',
#  'Pink Floyd: Live at Pompeii ',
#  'Frank Film ',
#  'Die große Ekstase des Bildschnitzers Steiner ',
#  'Jimi Hendrix ',
#  'The Last Chapter ',
#  'Une collection particulière ',
#  'Wattstax ',
#  'Animals Are Beautiful People ',
#  'A Bigger Splash ',
#  'Daguerréotypes ',
#  'Le dormeur ',
#  'Hearts and Minds ',
#  'Italianamerican ',
#  "That's Entertainment! ",
#  'Dow Rahehal Baraye yek Massaleh ',
#  'F for Fake ',
#  'Grey Gardens ',
#  'Yozhik v tumane ',
#  'Laboured Party ',
#  'Les princes noirs de Saint-Germain des Prés ',
#  'Harlan County U.S.A. ',
#  'Savana violenta ',
#  'The Song Remains the Same ',
#  "That's Entertainment, Part II ",
#  'Bruce Lee, the Legend ',
#  'The Grateful Dead ',
#  'News from Home ',
#  'Pumping Iron ',
#  'La Soufrière - Warten auf eine unausweichliche Katastrophe ',
#  'Gates of Heaven ',
#  'The Last Waltz ',
#  'Powers of Ten ',
#  'The Small One ',
#  'Ett anständigt liv ',
#  'Baby Snakes ',
#  '¡Que Viva Mexico! - Da zdravstvuyet Meksika! ',
#  'Richard Pryor: Live in Concert ',
#  'Skazka skazok ',
#  'AC/DC: Let There Be Rock ',
#  'Foutaises ',
#  'Gadajace glowy ',
#  'Garlic Is As Good As Ten Mothers ',
#  'In Search of Historic Jesus ',
#  'Be Tartib ya Bedoun-e Tartib ',
#  'The Decline of Western Civilization ',
#  'Zánik domu Usheru ',
#  'Genocide ',
#  'Reporters ',
#  'Vernon, Florida ',
#  'The Atomic Cafe ',
#  'Black Wax ',
#  'Burden of Dreams ',
#  'If You Love This Planet ',
#  "Let's Spend the Night Together ",
#  'Monty Python Live at the Hollywood Bowl ',
#  'Reassemblage: From the Firelight to the Screen ',
#  'Richard Pryor Live on the Sunset Strip ',
#  'Sans soleil ',
#  'The Snowman ',
#  'Vincent ',
#  'Eddie Murphy: Delirious ',
#  'Koyaanisqatsi ',
#  "Mickey's Christmas Carol ",
#  'Overnight Sensation ',
#  'Ziggy Stardust and the Spiders from Mars ',
#  'The Adventures of André and Wally B. ',
#  'Frankenweenie ',
#  'Hookers on Davie ',
#  'Stop Making Sense ',
#  'Streetwise ',
#  'Terror in the Aisles ',
#  'The Times of Harvey Milk ',
#  'Before Stonewall ',
#  'Broken Down Film ',
#  "Richard Pryor: Live and Smokin' ",
#  'Shoah ',
#  'Stripper ',
#  'Tokyo-Ga ',
#  'Captain EO ',
#  'Karins ansikte ',
#  'Luxo Jr. ',
#  "Chuck Berry Hail! Hail! Rock 'n' Roll ",
#  'Eddie Murphy Raw ',
#  'Yuki Yukite shingun ',
#  'Varázslat - Queen Budapesten ',
#  "Red's Dream ",
#  "Sign 'o' the Times ",
#  'Your Face ',
#  'Depeche Mode: 101 ',
#  'The Decline of Western Civilization Part II: The Metal Years ',
#  'Hôtel Terminus ',
#  'Imagine: John Lennon ',
#  "Let's Get Lost ",
#  'Mariya ',
#  'Muzné hry ',
#  'Powaqqatsi ',
#  'The Thin Blue Line ',
#  'Tin Toy ',
#  'Une histoire de vent ',
#  'Aufzeichnungen zu Kleidern und Städten ',
#  'Balance ',
#  'Champions Forever ',
#  'For All Mankind ',
#  'Helmut Newton: Frames from the Edge ',
#  'Kajsa Kavat ',
#  'Knick Knack ',
#  'Mashgh-e Shab ',
#  'Roger & Me ',
#  'Surname Viet Given Name Nam ',
#  'Cavallette ',
#  'Paris Is Burning ',
#  'The Road to God Knows Where ',
#  'Sink or Swim ',
#  'Yksinteoin ',
#  'Anima Mundi ',
#  'Atlantis ',
#  'The Disco Years ',
#  "Hearts of Darkness: A Filmmaker's Apocalypse ",
#  'Madonna: Truth or Dare ',
#  'Manipulation ',
#  'The Restless Conscience: Resistance to Hitler Within Germany 1933-1945 ',
#  'Talk 16 ',
#  'Aileen Wuornos: The Selling of a Serial Killer ',
#  'Baraka ',
#  "Beyond 'JFK': The Question of Conspiracy ",
#  'A Brief History of Time ',
#  "Brother's Keeper ",
#  'Female Misbehavior ',
#  'Fires of Kuwait ',
#  'Jídlo ',
#  'A Grand Day Out with Wallace and Gromit ',
#  'The JFK Assassination: The Jim Garrison Tapes ',
#  'Lektionen in Finsternis ',
#  'The Panama Deception ',
#  'Ett rättfärdigt krig? ',
#  'Stepping Razor: Red X ',
#  'Titanica ',
#  'Visions of Light ',
#  'Anna: Ot shesti do vosemnadtsati ',
#  'Glocken aus der Tiefe - Glaube und Aberglaube in Rußland ',
#  "D'Est ",
#  'Hated: GG Allin & the Murder Junkies ',
#  'Kanehsatake: 270 Years of Resistance ',
#  'Latcho Drom ',
#  'Die Macht der Bilder: Leni Riefenstahl ',
#  "Passage à l'acte ",
#  'Pool Days ',
#  'Det sociala arvet ',
#  'The War Room ',
#  'Wallace & Gromit in The Wrong Trousers ',
#  'Bottle Rocket ',
#  'ChickenHawk ',
#  'Crumb ',
#  'The Endless Summer 2 ',
#  'Ernesto Che Guevara, le journal de Bolivie ',
#  'A Friend of Dorothy ',
#  'Hoop Dreams ',
#  "Jupiter's Wife ",
#  'London ',
#  'Le moine et le poisson ',
#  'My Sweet Satan ',
#  'Pink Floyd: P. U. L. S. E. Live at Earls Court ',
#  "That's Entertainment! III ",
#  'Trevor ',
#  'Martin Lawrence: You So Crazy ',
#  'Death in Venice, CA ',
#  'A.K.A. Don Bonus ',
#  'Alkali, Iowa ',
#  'Bones of the Forest ',
#  'Carl Th. Dreyer: Min metier ',
#  'The Celluloid Closet ',
#  'A Close Shave ',
#  'Jetzt leben - Juden in Berlin ',
#  'Lumière et compagnie ',
#  'Nico Icon ',
#  'On Your Mark ',
#  'Salaam Cinema ',
#  'El secdleto de la tlompeta ',
#  'Synthetic Pleasures ',
#  'War Stories ',
#  "Who's Counting? Marilyn Waring on Sex, Lies and Global Economics ",
#  'Aldous Huxley: The Gravity of Light ',
#  'Esposados ',
#  'Fetishes ',
#  'Hands on a Hard Body: The Documentary ',
#  "Krzysztof Kieslowski: I'm So-So... ",
#  'The Line King: The Al Hirschfeld Story ',
#  "Microcosmos: Le peuple de l'herbe ",
#  "Nobody's Business ",
#  'Paradise Lost: The Child Murders at Robin Hood Hills ',
#  'T2 3-D: Battle Across Time ',
#  'When We Were Kings ',
#  '4 Little Girls ',
#  'Exil Shanghai ',
#  'Fast, Cheap &amp; Out of Control ',
#  'Full Tilt Boogie ',
#  'Ghosts ',
#  'Inside Out ',
#  'Jumpers ',
#  'Mission to Mir ',
#  'Must Be the Music ',
#  "Nunzio's Second Cousin ",
#  'Rhyme &amp; Reason ',
#  'Robinson in Space ',
#  'Die Salzmänner von Tibet ',
#  'Trekkies ',
#  'Waco: The Rules of Engagement ',
#  'Year of the Horse ',
#  'Everest ',
#  'Eagles: Hell Freezes Over ',
#  'Lily and Jim ',
#  'A Rustling of Leaves: Inside the Philippine Revolution ',
#  'Ghetto ',
#  'Ladies and Gentlemen, Mr. Leonard Cohen ',
#  'Roadkill: The Last Days of John Martin ',
#  "Des majorettes dans l'espace ",
#  'La vieille dame et les pigeons ',
#  'Public Housing ',
#  'Black Angel ',
#  'The Bloody Olive ',
#  'Blow Job ',
#  'Zorns Lemma ',
#  "Geri's Game ",
#  'The Life and Death of 9413, a Hollywood Extra ',
#  'Year of the Dogs ',
#  'Musuko no seishun ',
#  'Flames of Passion ',
#  'O Amor Natural ',
#  'Fallingwater: The Apprentices ',
#  'Blonde Cobra ',
#  'Cigarettes & Coffee ',
#  'The Dirk Diggler Story ',
#  'Kurt & Courtney ',
#  'Het ondergrondse orkest ',
#  'Window Water Baby Moving ',
#  'Modulations ',
#  'The Kiss ',
#  'Famous Fred ',
#  'Party Monster ',
#  'Wild Man Blues ',
#  'Doragon bôru Z ',
#  'Yes, Yes, Nanette ',
#  'Scratch ',
#  'Blockade ',
#  'Kelly Loves Tony ',
#  'The Brandon Teena Story ',
#  'Frank Lloyd Wright ',
#  'Little Dieter Needs to Fly ',
#  "The Leader, His Driver, and the Driver's Wife ",
#  'The Cruise ',
#  'Ontario: Land of Lakes ',
#  'Troops ',
#  'Annabelle Serpentine Dance ',
#  'Condo Painting ',
#  'En el espejo del cielo ',
#  'Kamen Raidâ tai Shokkâ ',
#  'Killing Us Softly ',
#  '10/65: Selbstverstümmelung ',
#  'The Killing of America ',
#  'Voyage au bout du monde ',
#  'Queen: Champions of the World ',
#  'Aftermath ',
#  '7p., cuis., s. de b., ... à saisir ',
#  'Les dites cariatides ',
#  'Ulysse ',
#  'Dirty Baby Does Fire Island ',
#  "Billy's Balloon ",
#  'Human Remains ',
#  'Achilles ',
#  'Boot Camp ',
#  'Karen Black Like Me ',
#  'SPF 2000 ',
#  'Divorce Iranian Style ',
#  'Elvis: Aloha from Hawaii ',
#  'Madonna: The Girlie Show - Live Down Under ',
#  'The Contraption ',
#  'Obrazy starého sveta ',
#  'Il mio viaggio in Italia ',
#  'Bunny ',
#  'American Pimp ',
#  'Emilie Muller ',
#  'De ydmygede ',
#  'Father Christmas ',
#  'American Movie ',
#  'The Living Museum ',
#  'Regret to Inform ',
#  'Sex: The Annabel Chong Story ',
#  'Buena Vista Social Club ',
#  'More ',
#  'Children ',
#  'Hitch ',
#  'Hitler - Eine Karriere ',
#  'En forårsdag i Helvede ',
#  'Diaries Notes and Sketches ',
#  'Méditerranée ',
#  'Mein liebster Feind - Klaus Kinski ',
#  'America così nuda, così violenta ',
#  'The Big Swallow ',
#  'Eight ',
#  'Keep the River on Your Right: A Modern Cannibal Tale ',
#  'Special Delivery ',
#  'Chris Rock: Bigger &amp; Blacker ',
#  'The Old Man and the Sea ',
#  'Painters Painting ',
#  'Lost, Lost, Lost ',
#  'Véronique et son cancre ',
#  'Aspen ',
#  'Poketto monsutâ: Pikachû no natsu-yasumi ',
#  'Poketto monsutâ: Pikachû tankentai ',
#  'De slag in de Javazee ',
#  '$30 ',
#  'Blackadder Back &amp; Forth ',
#  'Amalfi Way ',
#  'The Crimson Permanent Assurance ',
#  'Les 3 inventeurs ',
#  'Paranoid ',
#  "Something's Got to Give ",
#  '1992: El descubrimiento ',
#  'Beyond the Mat ',
#  'Carne ',
#  'John Henry ',
#  'Broadway by Light ',
#  'The Epic of Everest ',
#  'Outer Space ',
#  'Two Billion Hearts ',
#  'The Dadshuttle ',
#  'My Heart Is My Witness ',
#  'Pocket Desert: Confessions of a Snake Killer ',
#  'Kusa-meikyû ',
#  'A Galaxy Far, Far Away ',
#  'The Gay Shoe Clerk ',
#  'Koza ',
#  'Small Deaths ',
#  'Al hayatt al yawmiyah fi quariah suriyah ',
#  'Rejected ',
#  'Thumbtanic ',
#  'Dark Days ',
#  'The Filth and the Fury ',
#  'The Original Kings of Comedy ',
#  'Tackle Happy ',
#  'uristen@menny.hu ',
#  'After Stonewall ',
#  'Michael Jordan to the Max ',
#  'Sacrifice ',
#  'George Carlin: Back in Town ',
#  "George Carlin: Doin' It Again ",
#  "George Carlin: Jammin' in New York ",
#  'George Carlin: You Are All Diseased ',
#  'Les glaneurs et la glaneuse ',
#  'For the Birds ',
#  'George Carlin: Carlin on Campus ',
#  'Hop to It! ',
#  'On Location: George Carlin at Phoenix ',
#  'The Sam Kinison Family Entertainment Hour ',
#  'Adonis XIV ',
#  'Bird on a Wire ',
#  'Choke ',
#  "Dave Chappelle: Killin' Them Softly ",
#  '101 Rent Boys ',
#  'Ein flüchtiger Zug nach dem Orient ',
#  'The American Nightmare ',
#  'Backstage ',
#  'Age 13 ',
#  'Boys Beware ',
#  'A Day of Thanksgiving ',
#  'Narcotics: Pit of Despair ',
#  'Calle 54 ',
#  'Live Aid ',
#  'As I Was Moving Ahead Occasionally I Saw Brief Glimpses of Beauty ',
#  'Haití: Killing the Dream ',
#  'Children Underground ',
#  "The Endurance: Shackleton's Legendary Antarctic Expedition ",
#  'Polustanok ',
#  'Tokyo Girls ',
#  'Marlene Dietrich: Her Own Song ',
#  'Dokfa nai meuman ',
#  'Stoked: The Rise and Fall of Gator ',
#  'Ups and Downs ',
#  'Gayniggers from Outer Space ',
#  'U2: Under a Blood Red Sky ',
#  'Dogtown and Z-Boys ',
#  "Fists of Freedom: The Story of the '68 Summer Games ",
#  'Maldito - O Estranho Mundo de José Mojica Marins ',
#  'Stanley Kubrick: A Life in Pictures ',
#  'Thirdworld ',
#  'Cinemania ',
#  'Porn Star: The Legend of Ron Jeremy ',
#  'Elvis: The Comeback Special ',
#  'The Follow ',
#  'Star ',
#  'Terra para Rose ',
#  'The Bear ',
#  'George Carlin: Complaints &amp; Grievances ',
#  'Fast Film ',
#  'Space Station 3D ',
#  'Sherlock Holmes Baffled ',
#  'De Artificiali Perspectiva ',
#  'Fidel ',
#  "I Don't Know Jack ",
#  'Schneckentraum ',
#  'Dog ',
#  'Ghosts of the Abyss ',
#  'Vremena goda ',
#  'Notorious C.H.O. ',
#  'Worm ',
#  'God Grew Tired of Us: The Story of Lost Boys of Sudan ',
#  'Le peuple migrateur ',
#  'The Conscientious Objector ',
#  'Derrida ',
#  'The Kid Stays in the Picture ',
#  'Biggie and Tupac ',
#  'Pocket Monster: Pikachû no dokidoki kakurenbo ',
#  'When Louis Met... Jimmy ',
#  'Darkened Room ',
#  'Un coupable idéal ',
#  'Lost in La Mancha ',
#  'Le tempestaire ',
#  'War Photographer ',
#  'O Beautiful ',
#  'Bowling for Columbine ',
#  'Ram Dass, Fierce Grace ',
#  'Late Summer ',
#  '1 Giant Leap ',
#  'The Life of Larry ',
#  'The Smell of Burning Ants ',
#  'Standing in the Shadows of Motown ',
#  'Alefbay-e afghan ',
#  'Informe general sobre unas cuestiones de interés para una proyección pública ',
#  'L.T.R. ',
#  'Lewis & Clark: Great Journey West ',
#  'The Fog of War: Eleven Lessons from the Life of Robert S. McNamara ',
#  'Être et avoir ',
#  'When Boys Fly ',
#  'Wilfred ',
#  'Bob Dylan: 30th Anniversary Concert Celebration ',
#  'The Smashing Machine ',
#  'All the Love You Cannes! ',
#  "Come Together: A Night for John Lennon's Words and Music ",
#  "Freedom's Fury ",
#  'Jackass: The Movie ',
#  'Witness to Hope: The Life of Karol Wojtyla, Pope John Paul II ',
#  'The Trials of Henry Kissinger ',
#  'I Am Trying to Break Your Heart ',
#  'Comedian ',
#  'Blue Collar Comedy Tour: The Movie ',
#  'Robin Williams: Live on Broadway ',
#  'Bat Thumb ',
#  'Gambling, Gods and LSD ',
#  'Edifício Master ',
#  'Feast of Death ',
#  'Spellbound ',
#  'Khaneh siah ast ',
#  'Killing Us Softly 3 ',
#  '10 minuta ',
#  'My Wrongs 8245-8249 and 117 ',
#  'Ônibus 174 ',
#  'The Godthumb ',
#  'Born Rich ',
#  'Bukowski: Born into This ',
#  'Capturing the Friedmans ',
#  'Comandante ',
#  'A Decade Under the Influence ',
#  'Tupac: Resurrection ',
#  'The Weather Underground ',
#  'Nu ',
#  'This Is John ',
#  'Whatever We Do ',
#  'The Bullet-Proof Coat ',
#  'Most ',
#  'A Constant Forge ',
#  "D'autres mondes ",
#  'Rabbits ',
#  'Final Flight of the Osiris ',
#  'How They Get There ',
#  'Katedra ',
#  'De fem benspænd ',
#  'Earthlings ',
#  "H.H. Holmes: America's First Serial Killer ",
#  "Easy Riders, Raging Bulls: How the Sex, Drugs and Rock 'N' Roll Generation Saved Hollywood ",
#  'Carnival in April ',
#  'The Real Cancun ',
#  'Shrek 4-D ',
#  'Beef ',
#  'Fahrenheit 9/11 ',
#  'Ant Muzak ',
#  'Chavez: Inside the Coup ',
#  'Trekkies 2 ',
#  'Aileen: Life and Death of a Serial Killer ',
#  'Talk Salò ',
#  'UFOs: Past, Present, and Future ',
#  'The Second Renaissance Part I ',
#  'Hititler ',
#  'This Car Up ',
#  'The Last Secret ',
#  'The Soul of a Man ',
#  "Kid's Story ",
#  'End of the Century ',
#  'Faster ',
#  'Girlhood ',
#  'Maestro ',
#  'S-21, la machine de mort Khmère rouge ',
#  'Geometria ',
#  'Am Siel ',
#  'Hoshi no koe ',
#  'Festival Express ',
#  'Quintessence ',
#  'Beyond ',
#  'My Architect ',
#  'Tibet: Cry of the Snow Lion ',
#  'Die Geschichte vom weinenden Kamel ',
#  'Strangers ',
#  'Batman: Dead End ',
#  'Unsere Afrikareise ',
#  'Det perfekte menneske ',
#  'Arnulf Rainer ',
#  'Destino ',
#  'Moog ',
#  'My Date with Drew ',
#  'Petite lumière ',
#  'The Corporation ',
#  'Game Over: Kasparov and the Machine ',
#  'Los Angeles Plays Itself ',
#  'Touching the Void ',
#  "Pullin' the Devil by the Tail ",
#  'Cocaine Cowboys ',
#  'Hollands licht ',
#  'Paper Clips ',
#  'Harvie Krumpet ',
#  'Lezate divanegi ',
#  "Little Wolf's Book of Badness ",
#  'Fairuz, we hielden zoveel van mekaar ',
#  'Nekojiru-so ',
#  'Sicko ',
#  'Hans Teeuwen: Dat dan weer wel ',
#  'Metallica: Some Kind of Monster ',
#  'Wasp ',
#  "Born Into Brothels: Calcutta's Red Light Kids ",
#  'Dig! ',
#  'Riding Giants ',
#  'Searching for the Wrong-Eyed Jesus ',
#  'Finisterre ',
#  'Gan ',
#  'I Like Killing Flies ',
#  'Overnight ',
#  'Super Size Me ',
#  'Tarnation ',
#  'Control Room ',
#  'Roundhay Garden Scene ',
#  'Earth ',
#  "Boundin' ",
#  'Le dernier trappeur ',
#  'Superstar in a Housedress ',
#  'Lightning in a Bottle ',
#  'The Ister ',
#  'Blessing ',
#  'Memoria del saqueo ',
#  'Ceský sen ',
#  'Chris Rock: Never Scared ',
#  'Trances ',
#  '7:35 de la mañana ',
#  'Our Father ',
#  "Yo soy Boricua, pa'que tu lo sepas! ",
#  'Deathdealer: A Documentary ',
#  'Cashback ',
#  'Five Dedicated to Ozu ',
#  'The Chiefs ',
#  'The Mindscape of Alan Moore ',
#  'Doodlebug ',
#  'Michael Moore Hates America ',
#  'Rupture ',
#  'Peyzazh ',
#  'Lewis Black: Black on Broadway ',
#  'ABBA in Concert ',
#  'Aliens of the Deep ',
#  'Uchilishte za shampioni ',
#  'Inside Deep Throat ',
#  'American Hardcore ',
#  "Ce qu'il reste de nous ",
#  'How Arnold Won the West ',
#  'Simpan ',
#  'Tell Them Who You Are ',
#  'Sarah Silverman: Jesus Is Magic ',
#  'Be Here to Love Me: A Film About Townes Van Zandt ',
#  "Darwin's Nightmare ",
#  'Gunner Palace ',
#  'The Wild Parrots of Telegraph Hill ',
#  "Dave Chappelle: For What It's Worth ",
#  'Deep Sea ',
#  'Six Shooter ',
#  "Dave Chappelle's Block Party ",
#  'The Future of Food ',
#  'Grizzly Man ',
#  'Miles Electric: A Different Kind of Blue ',
#  'The Cutting Edge: The Magic of Movie Editing ',
#  'Draft ',
#  'March of the Penguins ',
#  'The World According to Sesame Street ',
#  'Forza Bastia ',
#  'Rare Exports Inc. ',
#  'Runaway ',
#  'Edgar G. Ulmer - The Man Off-screen ',
#  'The White Diamond ',
#  'The Aristocrats ',
#  'The Devil and Daniel Johnston ',
#  'Letters of Service ',
#  'Roving Mars ',
#  'Murderball ',
#  'Ring of Fire: The Emile Griffith Story ',
#  'Rize ',
#  'Twist of Faith ',
#  'Why We Fight ',
#  'Fuyu no hi ',
#  'Fußballweltmeisterschaft Chile 1962 ',
#  'Hummingbird ',
#  "I Know I'm Not Alone ",
#  'The Meaning of Life ',
#  '9 ',
#  'Jamie Foxx: Straight from the Foxxhole ',
#  'The Trials of Darryl Hunt ',
#  'We Jam Econo: The Story of the Minutemen ',
#  'Subway ',
#  'In Pursuit of Happiness ',
#  'Beyrouth après-rasage ',
#  'Living Luminaries: The Serious Business of Happiness ',
#  'The Comedians of Comedy ',
#  'Just for Kicks ',
#  "I'm Going to Tell You a Secret ",
#  '1973 ',
#  'Maradona by Kusturica ',
#  "The God Who Wasn't There ",
#  'Favela Rising ',
#  'Gay Sex in the 70s ',
#  'Modify ',
#  'A State of Mind ',
#  'Maniac 2: Mr. Robbie ',
#  'Al otro lado ',
#  "D'Annunzios Höhle ",
#  'Midnight Movies: From the Margin to the Mainstream ',
#  'Street Fight ',
#  'Through the Fire ',
#  'McLibel ',
#  'The Death of Salvador Dali ',
#  'Crossing the Bridge: The Sound of Istanbul ',
#  'Earnie ',
#  'Éramos pocos ',
#  'Deep Water ',
#  'Big Rig ',
#  'Spyz ',
#  'Night Swimming ',
#  'Phantom Limb ',
#  "The Howlin' Wolf Story ",
#  'Overcoming ',
#  'La leyenda del espantapájaros ',
#  'Oyun ',
#  'The Road to Guantanamo ',
#  'Back to Bosnia ',
#  'Marie Uguay ',
#  'Crossing the Line ',
#  'Neil Young: Heart of Gold ',
#  'Comedy Central Roast of Pamela Anderson ',
#  'Son smeshnogo cheloveka ',
#  'Gogol Bordello Non-Stop ',
#  'The U.S. vs. John Lennon ',
#  "Leonard Cohen: I'm Your Man ",
#  "Metal: A Headbanger's Journey ",
#  "Workingman's Death ",
#  'Zidane, un portrait du 21e siècle ',
#  'Zizek! ',
#  'Made in America ',
#  'One Man Band ',
#  'Gonzo: The Life and Work of Dr. Hunter S. Thompson ',
#  'Surfwise ',
#  'Chasing Ghosts: Beyond the Arcade ',
#  'Following Sean ',
#  'Michael Jackson Live in Bucharest: The Dangerous Tour ',
#  'Out Now ',
#  'The Madagascar Penguins in a Christmas Caper ',
#  'George Carlin: Life Is Worth Losing ',
#  'American Teen ',
#  'Jesus Camp ',
#  'Albert Fish: In Sin He Found Salvation ',
#  'Fuck ',
#  'Living with AIDS ',
#  'Who Killed the Electric Car? ',
#  'Going to Pieces: The Rise and Fall of the Slasher Film ',
#  'Once in a Lifetime: The Extraordinary Story of the New York Cosmos ',
#  'Iraq in Fragments ',
#  'So Much So Fast ',
#  'TV Junkie ',
#  'Wordplay ',
#  'Our Brand Is Crisis ',
#  'The 11th Hour ',
#  'Everyone Stares: The Police Inside Out ',
#  'Ashes and Snow ',
#  'Jackass Number Two ',
#  'This Film Is Not Yet Rated ',
#  'Severe Clear ',
#  'Knjiga rekorda Sutke ',
#  'Saw ',
#  'An Inconvenient Truth ',
#  'We Live in Public ',
#  'Industry of Love ',
#  'Met een Breierdeck ',
#  'Trui ',
#  "Jerry Seinfeld: 'I'm Telling You for the Last Time' ",
#  'Dirty Sanchez: The Movie ',
#  'Fabulous! The Story of Queer Cinema ',
#  'Before the Music Dies ',
#  "Don't Trip... He Ain't Through with Me Yet ",
#  'Jonestown: The Life and Death of Peoples Temple ',
#  'Maxed Out: Hard Times, Easy Credit and the Era of Predatory Lenders ',
#  'Shadow Company ',
#  'Rough Cut ',
#  'I Have Never Forgotten You: The Life & Legacy of Simon Wiesenthal ',
#  'Indiana Jones and the Temple of the Forbidden Eye ',
#  'Océans ',
#  'God Is My DJ ',
#  'Planet B-Boy ',
#  'Samsara ',
#  'Non métrage Libanais ',
#  'Get Thrashed ',
#  'First Flight ',
#  'Aldrig som första gången! ',
#  'Un lever de rideau ',
#  'Crazy Love ',
#  'Kurt Cobain About a Son ',
#  'Forbidden Lie$ ',
#  'Skid Row ',
#  'Wilde Salomé ',
#  'Hitchcocked ',
#  ...]

# %%
# Out:
# ['Edison Kinetoscopic Record of a Sneeze ', 'La sortie des usines Lumière ']

# %%
def find_similar_movies(movie_id):
    '''
    INPUT
    movie_id - a movie_id 
    OUTPUT
    similar_movies - an array of the most similar movies by title
    '''
    # find the row of each movie id
    pos_mv = np.where(movies['movie_id']==movie_id)[0][0]
    
    # find the most similar movie indices - to start I said they need to be the same for all content
    # retrieve ids from movieidIndexedMoviesDF based on positions in row
    row = dot_prod_movies[pos_mv,:]
    poses_sim_movs = np.where(row > 0)
    sim_mov_ids = [movieidIndexedMoviesDF.index[pos] for pos in poses_sim_movs]
    list_form = list(sim_mov_ids[0])
    
    # remove the movie itself
    list_form.remove(movie_id)
    
    # pull the movie titles based on the indices
    similar_movies = get_movie_names(mov_ids)
    
    return similar_movies
    
# You made this function in an earlier notebook - using again here    
def get_movie_names(movie_ids):
    '''
    INPUT
    movie_ids - a list of movie_ids
    OUTPUT
    movies - a list of movie names associated with the movie_ids
    
    '''
    movie_lst = list(movies[movies['movie_id'].isin(movie_ids)]['movie'])
   
    return movie_lst


def make_recs():
    '''
    INPUT
    None
    OUTPUT
    recs - a dictionary with keys of the user and values of the recommendations
    '''
    # Create dictionary to return with users and ratings
    recs = defaultdict(set)
    users = np.unique(reviews['user_id'])
    
    # How many users for progress bar
    n_users = len(users)
    
    # Create the progressbar
    cnter = 0
    bar = progressbar.ProgressBar(maxval=n_users+1, widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
    bar.start()
    
    # For each user
    for user in users:
        
        recs[user] = []

        # Update the progress bar
        cnter+=1 
        bar.update(cnter)

        # Pull only the reviews the user has seen
        usrRankedMovs = ratingRanked_reviews[\
                        ratingRanked_reviews['user_id']==user]
        
        # Look at each of the movies (highest ranked first), 
        for mov in usrRankedMovs['movie_id']:
            
            # pull the movies the user hasn't seen that are most similar
            sim_movs = find_similar_movies(movie_id)
            new_sim_movs = [mov for mov in sim_movs if mov not in recs[user]]
            
            # These will be the recommendations - continue until 10 recs 
            # or you have depleted the movie list for the user
            recs[user].append(new_sim_movs)
            
            if len(recs[user]) > 10: 
                recs[user] = recs[user][0:10]
                break

    # finish the progress bar
    bar.finish()
    
    return recs

# %%
recs = make_recs()

# %% [markdown]
# ### How Did We Do?
#
# Now that you have made the recommendations, how did we do in providing everyone with a set of recommendations?
#
# `4.` Use the cells below to see how many individuals you were able to make recommendations for, as well as explore characteristics about individuals who you were not able to make recommendations for.

# %%
# Explore recommendations

# %%
# Some characteristics of my content based recommendations
users_without_all_recs = #store user ids without recs
users_with_all_recs = # users with all recs here
no_recs = # users with no recommendations

print("There were {} users without all 10 recommendations we would have liked to have.".format(len(users_without_all_recs)))
print("There were {} users with all 10 recommendations we would like them to have.".format(len(users_with_all_recs)))
print("There were {} users with no recommendations at all!".format(len(no_recs)))

# %%
# Closer look at individual user characteristics - this may help it was from an earlier notebook
user_items = reviews[['user_id', 'movie_id', 'rating']]
user_by_movie = user_items.groupby(['user_id', 'movie_id'])['rating'].max().unstack()

def movies_watched(user_id):
    '''
    INPUT:
    user_id - the user_id of an individual as int
    OUTPUT:
    movies - an array of movies the user has watched
    '''
    movies = user_by_movie.loc[user_id][user_by_movie.loc[user_id].isnull() == False].index.values

    return movies


movies_watched(189)

# %%
# More exploring
print("Some of the movie lists for users without any recommendations include:")
# Just one of many questions you could continue exploring...

# %% [markdown]
# ### Now What?
#
# Well, if you were really strict with your criteria for how similar two movies (like I was initially), then you still have some users that don't have all 10 recommendations (and a small group of users who have no recommendations at all).
#
# As stated earlier, recommendation engines are a bit of an **art** and a **science**.  There are a number of things we still could look into - how do our collaborative filtering and content based recommendations compare to one another? How could we incorporate user input along with collaborative filtering and/or content based recommendations to improve any of our recommendations?  How can we truly gain recommendations for every user?
#
# `5.` In this last step feel free to explore any last ideas you have with the recommendation techniques we have looked at so far.  You might choose to make the final needed recommendations using the first technique with just top ranked movies.  You might also loosen up the strictness in the similarity needed between movies.  Be creative and share your insights with your classmates!

# %%
# Cells for exploring
